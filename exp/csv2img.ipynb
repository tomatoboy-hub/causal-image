# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../../")

# CSVファイルを読み込む
data = pd.read_csv('../../input/GeoKey801_BAND2.csv', header=None, skiprows=1)

# 画像のサイズに変換 (例えば、256x256ピクセルの画像の場合)
image = np.array(data).reshape((351, 351))



# 画像として表示
plt.imshow(image, cmap='gray')
plt.show()

# # データを0～255の範囲にスケーリング
# image_normalized = (image - np.min(image)) / (np.max(image) - np.min(image)) * 255

# # 画像として表示
# plt.imshow(image_normalized, cmap='gray')
# plt.show()

# %%
df = pd.read_csv("../../input/UgandaDataProcessed.csv")
# Out:
# /tmp/ipykernel_32304/3496303127.py:1: DtypeWarning: Columns (5,6,7,89,536,540,542,544,555,589,590,591,592,593,594,595,596,597,640,667,671,680,693,699,705,711,717,723,729,735,741,747,753,759,765,771,777,809,812,814,816,818,820,822,873,880,883,886,891,894,895,897,902,906,917,919,939,967,971,1005,1014,1037,1039,1047,1049,1057,1059,1067,1069,1077,1079,1087,1089,1097,1099,1107,1109,1117,1119,1127,1129,1139,1147,1149,1159,1169,1177,1179,1189,1197,1199,1209,1229,1237,1239,1249,1257,1259,1267,1269,1280,1314,1318,1323,1360,1444,1445,1450,1528,1531,1534,1553,1555,1571,1574,1575,2327,2332,2335,2339,2348,2356,2361,2364,2369,2378,2387,2392,2394,2398,2406,2415,2420,2423,2427,2435,2443,2448,2451,2456,2465,2473,2478,2482,2486,2495,2526,2536,2541,2545,2550,2559,2568,2573,2575,2579,2588,2595,2600,2603,2608,2617,2626,2631,2633,2637,2645,2653,2658,2661,2665,2673,2681,2686,2688,2692,2700,2707,2712,2715,2719,2729,2736,2741,2744,2748,2757,2765,2770,2773,2777,2786,2792,2817,2827,2832,2835,2840,2849,2895,289
# ...

# %%
df.head()
# Out:
#      MERGE_ID       X   P_02_ID.x  geo_long_center  geo_lat_center  \
# 0  20810108.0  3835.0  20810108.0        34.092798        1.313679
# 1  20810108.0  3835.0  20810108.0        34.092798        1.313679
# 2  20810108.0  3835.0  20810108.0        34.092798        1.313679
# 3  20810108.0  3835.0  20810108.0        34.092798        1.313679
# 4  20810108.0  3835.0  20810108.0        34.092798        1.313679
#
#   PNAME_VALUE SNAME_2002 geolocated_failed  dist_geolocation   geo_long  ...  \
# 0      KOKUTU    BUKEDEA             False       1172.159911  34.087529  ...
# 1      KOKUTU    BUKEDEA             False       1172.159911  34.087529  ...
# 2      KOKUTU    BUKEDEA             False       1172.159911  34.087529  ...
# 3      KOKUTU    BUKEDEA             False       1172.159911  34.087529  ...
# 4      KOKUTU    BUKEDEA             False       1172.159911  34.087529  ...
#
#    human_capital_index_e     comp1     comp2     comp3  comp4       new  Wobs  \
# ...

# %%
len(df.columns)
# Out:
# 6011
