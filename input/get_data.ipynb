# %% [markdown]
# # get_data.ipynb
#
# これはkaggleのデータセットから画像データを取得するNotebookです

# %%
import sys
sys.path.append("../")

# %%
import pandas as pd
df = pd.read_csv('All Appliances.csv')
df.head()
# Out:
#                                                 name main_category  \
# 0  Pigeon by Stovekraft Amaze Plus Electric Kettl...    appliances
# 1  Pigeon Polypropylene Mini Handy and Compact Ch...    appliances
# 2  Glun Multipurpose Portable Electronic Digital ...    appliances
# 3  beatXP Kitchen Scale Multipurpose Portable Ele...    appliances
# 4  Bajaj DX-6 1000W Dry Iron with Advance Solepla...    appliances
#
#      sub_category                                              image  \
# 0  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
len(df)
# Out:
# 9576

# %%
import urllib.request
import time
for i, row in df.iterrows():
    url = str(row["image"])
    print(url)
    try:
        time.sleep(0.5)
        urllib.request.urlretrieve(url, f"/root/graduation_thetis/input/images/{i}.jpg")
        row["img_path"] = f"/root/graduation_thetis/input/images/{i}.jpg"
    except:
        row["img_path"] = None
# Out:
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/51DGcy8eBCL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/51RXzjrUmkL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/61ocesEh0cL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/61Is7sICRJL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/61qgKaW71mL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/41XJ2wk4M1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/31hmQqq7KsL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/71zlLSHbJ-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/7152-mn8mKL._AC_UL320_.jpg
# https://m.media-amazon.com/images/W/IMAGERENDERING_521856-T1/images/I/71SxUzhnLvL._AC_UL320_.jpg
# ...

# %%
import os

for i, row in df.iterrows():
    img_path = f"/root/graduation_thetis/input/images/{i}.jpg"
    if os.path.exists(img_path):
        df.at[i, "img_path"] = img_path  # ファイルが存在する場合はパスを設定
    else:
        df.at[i, "img_path"] = None  # 存在しない場合はNoneを設定

# %%
df.to_csv("./All Appliances_img.csv")
